# %%
! aws s3 ls ws-in/ssebop/ndvi/2012/
# Out:
# 2022-08-30 03:54:59          0
# 2022-08-30 03:05:00         83 2012011.1_km_VIIRS_NDVI.tfw
# 2022-08-30 03:06:10  296520105 2012011.1_km_VIIRS_NDVI.tif
# 2022-08-30 03:06:12       2658 2012011.1_km_VIIRS_NDVI.tif.aux.xml
# 2022-08-30 03:06:34   82068100 2012011.1_km_VIIRS_NDVI.tif.ovr
# 2022-08-30 03:06:36          5 2012011.1_km_VIIRS_NDVI.tif.vat.cpg
# 2022-08-30 03:06:37     588128 2012011.1_km_VIIRS_NDVI.tif.vat.dbf
# 2022-08-30 03:06:37       6800 2012011.1_km_VIIRS_NDVI.tif.xml
# 2022-08-30 03:06:38         83 2012012.1_km_VIIRS_NDVI.tfw
# 2022-08-30 03:07:34  296520105 2012012.1_km_VIIRS_NDVI.tif
# 2022-08-30 03:07:41       2658 2012012.1_km_VIIRS_NDVI.tif.aux.xml
# 2022-08-30 03:07:54   82068100 2012012.1_km_VIIRS_NDVI.tif.ovr
# 2022-08-30 03:07:56          5 2012012.1_km_VIIRS_NDVI.tif.vat.cpg
# 2022-08-30 03:07:56     588128 2012012.1_km_VIIRS_NDVI.tif.vat.dbf
# 2022-08-30 03:07:57       6800 2012012.1_km_VIIRS_NDVI.tif.xml
# ...

# %%
ndvi_tif = 'ws-in/ssebop/ndvi/2012/2012021.1_km_VIIRS_NDVI.tif'

# %%
import xarray as xr
import rioxarray

# %%
# - depricated - da = xr.open_rasterio(f's3://{ndvi_tif}')

# %%
d_ndvi = rioxarray.open_rasterio(f's3://{ndvi_tif}')

# %%
d_ndvi
# Out:
# <xarray.DataArray (band: 1, y: 14505, x: 37298)>
# [541007490 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * y            (y) float64 80.0 79.99 79.98 79.97 ... -59.98 -59.99 -60.0
#     spatial_ref  int64 0
# Attributes: (12/15)
#     AREA_OR_POINT:           Area
#     DataType:                Generic
#     BandName:                Band_1
#     RepresentationType:      THEMATIC
#     STATISTICS_COVARIANCES:  3714678.674746278
#     STATISTICS_MAXIMUM:      9997
#     ...                      ...
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       1927.350169208
#     _FillValue:              -32768
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               Band_1

# %%
mys3path = 'ws-in/ssebop/lst/2012/'
tif='2012021.1_km_VIIRS_LST.tif'

s3_tif_object=mys3path+tif

# %%
d_lst = rioxarray.open_rasterio(f's3://{s3_tif_object}')

# %%
d_lst
# Out:
# <xarray.DataArray (band: 1, y: 14505, x: 37298)>
# [541007490 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * y            (y) float64 80.0 79.99 79.98 79.97 ... -59.98 -59.99 -60.0
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:       Area
#     RepresentationType:  ATHEMATIC
#     _FillValue:          -3.4028235e+38
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
#d_lst = d_lst.assign_coords(band=['lst'])

# %%
d_lst
# Out:
# <xarray.DataArray (band: 1, y: 14505, x: 37298)>
# [541007490 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * y            (y) float64 80.0 79.99 79.98 79.97 ... -59.98 -59.99 -60.0
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:       Area
#     RepresentationType:  ATHEMATIC
#     _FillValue:          -3.4028235e+38
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
# d_ndvi = d_ndvi.squeeze().drop(labels='band')

# d_lst = d_lst.squeeze().drop(labels='band')
# #da.name=product

# %%
#d_ndvi = d_ndvi.assign_coords(band=['ndvi'])

# %%
d_ndvi
# Out:
# <xarray.DataArray (band: 1, y: 14505, x: 37298)>
# [541007490 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * y            (y) float64 80.0 79.99 79.98 79.97 ... -59.98 -59.99 -60.0
#     spatial_ref  int64 0
# Attributes: (12/15)
#     AREA_OR_POINT:           Area
#     DataType:                Generic
#     BandName:                Band_1
#     RepresentationType:      THEMATIC
#     STATISTICS_COVARIANCES:  3714678.674746278
#     STATISTICS_MAXIMUM:      9997
#     ...                      ...
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       1927.350169208
#     _FillValue:              -32768
#     scale_factor:            1.0
#     add_offset:              0.0
#     long_name:               Band_1

# %%
d_lst
# Out:
# <xarray.DataArray (band: 1, y: 14505, x: 37298)>
# [541007490 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * y            (y) float64 80.0 79.99 79.98 79.97 ... -59.98 -59.99 -60.0
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:       Area
#     RepresentationType:  ATHEMATIC
#     _FillValue:          -3.4028235e+38
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
d_lst.name='lst'

# %%
d_ndvi.name='ndvi'

# %%
my_science_da = xr.concat([d_lst, d_ndvi], dim='band')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 my_science_da = xr.concat([d_lst, d_ndvi], dim='band')
#
# File /wsefs/miniconda3/envs/ssebop-study/lib/python3.10/site-packages/xarray/core/concat.py:231, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     226     raise ValueError(
#     227         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     228     )
#     230 if isinstance(first_obj, DataArray):
# --> 231     return _dataarray_concat(
#     232         objs,
#     233         dim=dim,
#     234         data_vars=data_vars,
#     235         coords=coords,
#     236         compat=compat,
#     237         positions=positions,
#     238         fill_value=fill_value,
#     239         join=join,
# ...

# %%
my_science_da

# %%
d_ndvi
